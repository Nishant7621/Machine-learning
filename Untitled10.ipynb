# %% [markdown]
# <a href="https://colab.research.google.com/github/Nishant7621/Nishant7621/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt # visualizing data
import sklearn.linear_model as linear_model

# %%
df=pd.read_csv('/content/placement-dataset.csv')

# %%
df.shape
# Out:
# (100, 4)

# %%
df.head(10)
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0
# 5           5   7.1   48.0          1
# 6           6   5.7  143.0          0
# 7           7   5.0   63.0          0
# 8           8   6.1  156.0          0
# 9           9   5.1   66.0          0

# %%
df.dtypes
# Out:
# Unnamed: 0      int64
# cgpa          float64
# iq            float64
# placement       int64
# dtype: object

# %%
df['cgpa']=df['cgpa'].astype('int')

# %%
plt.scatter(df['cgpa'],df['placement'])
plt.plot(df['cgpa'],df['placement'])
plt.xlabel('cgpa')
plt.ylabel('placement')
plt.title("placement & cgpa")
# Out:
# Text(0.5, 1.0, 'placement & cgpa')

# %%
x=df.iloc[:,0:1]
y=df.iloc[:,-1]

# %%
x
# Out:
#     Unnamed: 0
# 0            0
# 1            1
# 2            2
# 3            3
# 4            4
# ..         ...
# 95          95
# 96          96
# 97          97
# 98          98
# 99          99
#
# [100 rows x 1 columns]

# %%
y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_test,y_test)
# Out:
# LinearRegression()

# %%
y_test
# Out:
# array([[300000.        ],
#        [240000.        ],
#        [500000.        ],
#        [218000.        ],
#        [240000.        ],
#        [500000.        ],
#        [260000.        ],
#        [288655.40540541],
#        [288655.40540541],
#        [250000.        ],
#        [260000.        ],
#        [210000.        ],
#        [250000.        ],
#        [288655.40540541],
#        [220000.        ],
#        [300000.        ],
#        [240000.        ],
#        [300000.        ],
#        [288655.40540541],
#        [288655.40540541],
#        [240000.        ],
#        [200000.        ],
#        [270000.        ],
#        [200000.        ],
#        [300000.        ],
#        [295000.        ],
#        [288655.40540541],
#        [220000.        ],
#        [450000.        ],
#        [360000.        ],
#        [252000.        ],
#        [280000.        ],
#        [280000.        ],
#        [300000.        ],
#        [288655.40540541],
# ...

# %%
x_test
# Out:
#     Unnamed: 0
# 83          83
# 30          30
# 56          56
# 24          24
# 16          16
# 23          23
# 2            2
# 27          27
# 28          28
# 13          13
# 99          99
# 92          92
# 76          76
# 14          14
# 0            0
# 21          21
# 3            3
# 29          29
# 61          61
# 79          79

# %%
lr.predict(x_test.iloc[2].values.reshape(1,1))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([0.5661751])

# %%
plt.scatter(df['cgpa'],df['placement'])
plt.plot(x_test,lr.predict(x_test))
plt.xlabel('cgpa')
plt.ylabel('placement')
# Out:
# Text(0, 0.5, 'placement')

# %%
m=lr.coef_[0]

# %%
b=lr.intercept_

# %%
m * 8 + b
# Out:
# 0.5210352809871237
