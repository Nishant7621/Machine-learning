# %%
import pandas as pd

# %%
df=pd.read_csv('employee_data.csv')

# %%
df.shape[1]
# Out:
# 26

# %%
df.head()
# Out:
#    EmpID FirstName LastName  StartDate ExitDate                    Title  \
# 0   3427     Uriah  Bridges  20-Sep-19      NaN  Production Technician I
# 1   3428     Paula    Small  11-Feb-23      NaN  Production Technician I
# 2   3429    Edward     Buck  10-Dec-18      NaN       Area Sales Manager
# 3   3430   Michael  Riordan  21-Jun-21      NaN       Area Sales Manager
# 4   3431   Jasmine    Onque  29-Jun-19      NaN       Area Sales Manager
#
#         Supervisor                        ADEmail BusinessUnit EmployeeStatus  \
# 0     Peter Oneill    uriah.bridges@bilearner.com         CCDR         Active
# 1  Renee Mccormick      paula.small@bilearner.com           EW         Active
# 2   Crystal Walker      edward.buck@bilearner.com           PL         Active
# 3   Rebekah Wright  michael.riordan@bilearner.com         CCDR         Active
# 4        Jason Kim    jasmine.onque@bilearner.com          TNS         Active
#
# ...

# %%
df.iloc[0]
# Out:
# EmpID                                                3427
# FirstName                                           Uriah
# LastName                                          Bridges
# StartDate                                       20-Sep-19
# ExitDate                                              NaN
# Title                             Production Technician I
# Supervisor                                   Peter Oneill
# ADEmail                       uriah.bridges@bilearner.com
# BusinessUnit                                         CCDR
# EmployeeStatus                                     Active
# EmployeeType                                     Contract
# PayZone                                            Zone C
# EmployeeClassificationType                      Temporary
# TerminationType                                       Unk
# TerminationDescription                                NaN
# DepartmentType                          Production
# ...

# %%
df.iloc[1:3]
# Out:
#    EmpID FirstName LastName  StartDate ExitDate                    Title  \
# 1   3428     Paula    Small  11-Feb-23      NaN  Production Technician I
# 2   3429    Edward     Buck  10-Dec-18      NaN       Area Sales Manager
#
#         Supervisor                    ADEmail BusinessUnit EmployeeStatus  \
# 1  Renee Mccormick  paula.small@bilearner.com           EW         Active
# 2   Crystal Walker  edward.buck@bilearner.com           PL         Active
#
#    ...       Division         DOB State JobFunctionDescription GenderCode  \
# 1  ...         Aerial  30-08-1965    MA                  Labor       Male
# 2  ...  General - Sga  06-10-1991    MA              Assistant       Male
#
#   LocationCode  RaceDesc MaritalDesc Performance Score Current Employee Rating
# 1         6593  Hispanic     Widowed       Fully Meets                       3
# 2         2330  Hispanic     Widowed       Fully Meets                       4
#
# [2 rows x 26 columns]

# %%
df.iloc[[1,5,6]]
# Out:
#    EmpID FirstName LastName  StartDate   ExitDate                    Title  \
# 1   3428     Paula    Small  11-Feb-23        NaN  Production Technician I
# 5   3432     Maruk   Fraval  17-Jan-20        NaN       Area Sales Manager
# 6   3433     Latia    Costa  06-Apr-22  03-Jul-23       Area Sales Manager
#
#         Supervisor                     ADEmail BusinessUnit EmployeeStatus  \
# 1  Renee Mccormick   paula.small@bilearner.com           EW         Active
# 5     Sheri Campos  maruk.fraval@bilearner.com          BPC         Active
# 6      Jacob Braun   latia.costa@bilearner.com          WBL         Active
#
#    ...          Division         DOB State JobFunctionDescription GenderCode  \
# 1  ...            Aerial  30-08-1965    MA                  Labor       Male
# 5  ...  Field Operations  03-04-1949    CT                 Driver       Male
# 6  ...     General - Eng  01-07-1942    CA             Technician     Female
#
# ...

# %%
df.iloc[:,[4,5,6]]
# Out:
#        ExitDate                    Title          Supervisor
# 0           NaN  Production Technician I        Peter Oneill
# 1           NaN  Production Technician I     Renee Mccormick
# 2           NaN       Area Sales Manager      Crystal Walker
# 3           NaN       Area Sales Manager      Rebekah Wright
# 4           NaN       Area Sales Manager           Jason Kim
# ...         ...                      ...                 ...
# 2995  07-Aug-22  Production Technician I      Bethany Carter
# 2996        NaN  Production Technician I     Caroline Harris
# 2997  04-Aug-22  Production Technician I  Mr. James Castillo
# 2998  23-Oct-21  Production Technician I       Michael Woods
# 2999        NaN  Production Technician I       Javier Mccall
#
# [3000 rows x 3 columns]

# %%
df['LocationCode']==2330
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 2995    False
# 2996    False
# 2997    False
# 2998    False
# 2999    False
# Name: LocationCode, Length: 3000, dtype: bool

# %%
mask=df['LocationCode']==2330
df[mask]
# Out:
#       EmpID FirstName LastName  StartDate   ExitDate  \
# 2      3429    Edward     Buck  10-Dec-18        NaN
# 891    1318       Nan    Singh  29-Jul-23  04-Aug-23
# 1306   1733     Shana  Maurice  23-Oct-19  03-Dec-20
# 1530   1957    Melisa    Gerke  13-May-19  30-May-22
#
#                          Title      Supervisor                      ADEmail  \
# 2           Area Sales Manager  Crystal Walker    edward.buck@bilearner.com
# 891   Administrative Assistant   Donald Decker      nan.singh@bilearner.com
# 1306   Production Technician I     Joshua Ward  shana.maurice@bilearner.com
# 1530   Production Technician I       Jimmy Cox   melisa.gerke@bilearner.com
#
#      BusinessUnit          EmployeeStatus  ...          Division         DOB  \
# 2              PL                  Active  ...     General - Sga  06-10-1991
# 891           WBL                  Active  ...  Field Operations  14-05-1984
# 1306           EW                  Active  ...  Field Operations  15-02-1950
# ...

# %%
mask=df['LocationCode']==2330
df[mask].shape[0]
# Out:
# 4

# %%
mask=df['Division']=='General - Sga'
df[mask].shape[0]
# Out:
# 117

# %%
def get_city_match_count(LocationCode):
    mask=df['LocationCode']==LocationCode
    return df[mask].shape[0]

# %%
get_city_match_count(2330)
# Out:
# 4

# %%
mask1=df['Division']=='General - Sga'
mask2=df['StartDate']>'20-Sep-19'
df[mask1 & mask2].shape[0]
# Out:
# 38

# %%
df['Division'].value_counts()
# Out:
# Division
# Field Operations            789
# General - Con               509
# Engineers                   275
# Aerial                      196
# Wireline Construction       180
# Project Management - Con    178
# General - Sga               117
# Splicing                    110
# General - Eng                86
# Fielders                     82
# Finance & Accounting         70
# Yard (Material Handling)     59
# Catv                         58
# Shop (Fleet)                 57
# Executive                    43
# Wireless                     33
# Underground                  33
# Technology / It              26
# People Services              25
# Billable Consultants         24
# Project Management - Eng     16
# Isp                          14
# Sales & Marketing             9
# Safety                        9
# Corp Operations               2
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
df['EmployeeStatus'].value_counts()
# Out:
# EmployeeStatus
# Active                    2458
# Voluntarily Terminated     321
# Leave of Absence            86
# Future Start                69
# Terminated for Cause        66
# Name: count, dtype: int64

# %%
df['Division'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Division'>

# %%
df['Division'].value_counts().head().plot(kind='bar')
# Out:
# <Axes: xlabel='Division'>

# %%
df['Division'].value_counts().head().plot(kind='barh')
# Out:
# <Axes: ylabel='Division'>

# %%
df['Division'].value_counts().head().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df['Division'].value_counts().head().plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
myseries=df['Division'].value_counts()

# %%
myseries.index
# Out:
# Index(['Field Operations', 'General - Con', 'Engineers', 'Aerial',
#        'Wireline Construction', 'Project Management - Con', 'General - Sga',
#        'Splicing', 'General - Eng', 'Fielders', 'Finance & Accounting',
#        'Yard (Material Handling)', 'Catv', 'Shop (Fleet)', 'Executive',
#        'Wireless', 'Underground', 'Technology / It', 'People Services',
#        'Billable Consultants', 'Project Management - Eng', 'Isp',
#        'Sales & Marketing', 'Safety', 'Corp Operations'],
#       dtype='object', name='Division')

# %%
myseries.values
# Out:
# array([789, 509, 275, 196, 180, 178, 117, 110,  86,  82,  70,  59,  58,
#         57,  43,  33,  33,  26,  25,  24,  16,  14,   9,   9,   2])

# %%
myseries.tail()
# Out:
# Division
# Project Management - Eng    16
# Isp                         14
# Sales & Marketing            9
# Safety                       9
# Corp Operations              2
# Name: count, dtype: int64

# %%
myseries['Finance & Accounting']
# Out:
# np.int64(70)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 26 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   EmpID                       3000 non-null   int64
#  1   FirstName                   3000 non-null   object
#  2   LastName                    3000 non-null   object
#  3   StartDate                   3000 non-null   object
#  4   ExitDate                    1533 non-null   object
#  5   Title                       3000 non-null   object
#  6   Supervisor                  3000 non-null   object
#  7   ADEmail                     3000 non-null   object
#  8   BusinessUnit                3000 non-null   object
#  9   EmployeeStatus              3000 non-null   object
#  10  EmployeeType                3000 non-null   object
#  11  PayZone                     3000 non-null   object
#  12  EmployeeClassificationType  3000 non-null   object
# ...

# %%
df.columns
# Out:
# Index(['EmpID', 'FirstName', 'LastName', 'StartDate', 'ExitDate', 'Title',
#        'Supervisor', 'ADEmail', 'BusinessUnit', 'EmployeeStatus',
#        'EmployeeType', 'PayZone', 'EmployeeClassificationType',
#        'TerminationType', 'TerminationDescription', 'DepartmentType',
#        'Division', 'DOB', 'State', 'JobFunctionDescription', 'GenderCode',
#        'LocationCode', 'RaceDesc', 'MaritalDesc', 'Performance Score',
#        'Current Employee Rating'],
#       dtype='object')

# %%
(df['EmpID'].value_counts() + df['Performance Score'].value_counts()).sort_values()
# Out:
# 1001                NaN
# 1002                NaN
# 1003                NaN
# 1004                NaN
# 1005                NaN
#                      ..
# 4000                NaN
# Exceeds             NaN
# Fully Meets         NaN
# Needs Improvement   NaN
# PIP                 NaN
# Name: count, Length: 3004, dtype: float64

# %%
df.sort_values('FirstName',ascending=True)
# Out:
#       EmpID FirstName  LastName  StartDate   ExitDate  \
# 1381   1808     Aaden    Mercer  26-Jul-23        NaN
# 356    3783   Aaliyah     Watts  09-May-20        NaN
# 2529   2956     Aarav  Espinoza  11-Nov-19        NaN
# 1111   1538     Aaron     Tapia  20-Jan-23        NaN
# 114    3541     Aaron     Weber  06-Apr-20  24-Jul-23
# ...     ...       ...       ...        ...        ...
# 1065   1492      Zoey    Spence  06-May-20        NaN
# 1390   1817      Zoey      Page  06-May-19  09-Apr-22
# 345    3772      Zoie   Rowland  08-Feb-22  22-Jul-22
# 2961   3388      Zoie     Logan  19-Apr-19        NaN
# 1062   1489      Zoie   Mercado  01-Dec-20        NaN
#
#                          Title         Supervisor  \
# 1381   Production Technician I    Victoria Jacobs
# 356    Production Technician I    Jared Whitehead
# 2529   Production Technician I          David Ali
# 1111  Production Technician II       Michael Reed
# 114         Area Sales Manager     Melanie Garcia
# ...

# %%
df.shape
# Out:
# (3000, 26)

# %%
df.drop_duplicates(subset=['FirstName'])
# Out:
#       EmpID FirstName  LastName  StartDate   ExitDate  \
# 0      3427     Uriah   Bridges  20-Sep-19        NaN
# 1      3428     Paula     Small  11-Feb-23        NaN
# 2      3429    Edward      Buck  10-Dec-18        NaN
# 3      3430   Michael   Riordan  21-Jun-21        NaN
# 4      3431   Jasmine     Onque  29-Jun-19        NaN
# ...     ...       ...       ...        ...        ...
# 2962   3389    Finley    Medina  12-Aug-20        NaN
# 2973   3400   Lorenzo     Short  21-Sep-21        NaN
# 2984   3411    Brenda     Boone  06-Oct-22        NaN
# 2986   3413   Jovanny  Matthews  25-Nov-19        NaN
# 2995   3422    Jakobe  Erickson  22-Jun-22  07-Aug-22
#
#                          Title       Supervisor  \
# 0      Production Technician I     Peter Oneill
# 1      Production Technician I  Renee Mccormick
# 2           Area Sales Manager   Crystal Walker
# 3           Area Sales Manager   Rebekah Wright
# 4           Area Sales Manager        Jason Kim
# ...

# %%
df.drop_duplicates('Division',keep='last')[['Division','LocationCode']].sort_values('Division')
# Out:
#                       Division  LocationCode
# 2998                    Aerial          3807
# 2963      Billable Consultants         90024
# 2920                      Catv         17960
# 2169           Corp Operations         68985
# 2996                 Engineers         35444
# 2883                 Executive         53426
# 2999          Field Operations         57487
# 2961                  Fielders         48911
# 2989      Finance & Accounting         46381
# 2992             General - Con         39578
# 2984             General - Eng         24028
# 2964             General - Sga          2225
# 2735                       Isp         57257
# 2983           People Services         41572
# 2945  Project Management - Con         94040
# 2398  Project Management - Eng         80760
# 2819                    Safety         16673
# 2741         Sales & Marketing         86333
# 2985              Shop (Fleet)         68155
# 2990                  Splicing         71282
# ...

# %%
data=df.groupby('Division')

# %%
data

# %%
data.size().sort_values(ascending=False)
# Out:
# Division
# Field Operations            789
# General - Con               509
# Engineers                   275
# Aerial                      196
# Wireline Construction       180
# Project Management - Con    178
# General - Sga               117
# Splicing                    110
# General - Eng                86
# Fielders                     82
# Finance & Accounting         70
# Yard (Material Handling)     59
# Catv                         58
# Shop (Fleet)                 57
# Executive                    43
# Wireless                     33
# Underground                  33
# Technology / It              26
# People Services              25
# Billable Consultants         24
# Project Management - Eng     16
# Isp                          14
# Safety                        9
# Sales & Marketing             9
# Corp Operations               2
# dtype: int64

# %%
len(data)
# Out:
# 25

# %%
data.last()
# Out:
#                           EmpID FirstName    LastName  StartDate   ExitDate  \
# Division
# Aerial                     3425    Kendra       Braun  28-May-19  23-Oct-21
# Billable Consultants       3390    Lizeth   Middleton  21-Oct-22  05-Jan-23
# Catv                       3347     Ahmed     Lindsey  02-Feb-21  13-May-22
# Corp Operations            2596  Thaddeus        Lutz  16-Oct-21  04-May-22
# Engineers                  3423    Adyson  Strickland  28-Dec-20  07-Aug-22
# Executive                  3310    George       Fritz  02-Feb-22  04-Feb-23
# Field Operations           3426     Chace        Kerr  27-Apr-22  05-Aug-22
# Fielders                   3388      Zoie       Logan  19-Apr-19  29-Mar-23
# Finance & Accounting       3416      Aron      Waters  02-Oct-20  26-Apr-23
# General - Con              3419   Stanley       Reyes  14-Oct-19  03-Sep-22
# General - Eng              3411    Brenda       Boone  06-Oct-22  10-May-23
# ...

# %%
data.get_group('Wireless')
# Out:
#       EmpID FirstName    LastName  StartDate   ExitDate  \
# 105    3532    Marlon        Ford  14-Oct-21        NaN
# 194    3621  Victoria      Franco  28-Nov-18        NaN
# 269    3696      Aldo        Dyer  02-Sep-20  26-May-23
# 308    3735     Chace        Gray  29-May-19        NaN
# 391    3818    Carlos      Merlos  02-Jan-20  03-Apr-22
# 455    3882     Litzy     Esparza  30-Jan-19        NaN
# 459    3886   Britney       Kelly  12-Oct-18        NaN
# 483    3910     Caleb   Schneider  13-Jul-22  22-Jan-23
# 499    3926   Jeffery      Gamble  27-Feb-19        NaN
# 650    1077     Derek      Moreno  02-Feb-19        NaN
# 804    1231      Colt      Archer  07-Mar-20        NaN
# 820    1247   Ashanti       Scott  04-Mar-19        NaN
# 964    1391    Taylor      Sparks  02-Apr-20        NaN
# 1295   1722    Ronnie      Dillon  22-Feb-22        NaN
# 1335   1762    Lauren        Kent  04-Jul-23  12-Jul-23
# 1369   1796    Emmett     Mercado  07-Jun-21  13-Dec-22
# ...

# %%
data.get_group('Wireless').shape
# Out:
# (33, 26)

# %%
df.dropna(subset=['ExitDate','StartDate']).shape
# Out:
# (1533, 26)

# %%
df
# Out:
#       EmpID FirstName    LastName  StartDate   ExitDate  \
# 0      3427     Uriah     Bridges  20-Sep-19        NaN
# 1      3428     Paula       Small  11-Feb-23        NaN
# 2      3429    Edward        Buck  10-Dec-18        NaN
# 3      3430   Michael     Riordan  21-Jun-21        NaN
# 4      3431   Jasmine       Onque  29-Jun-19        NaN
# ...     ...       ...         ...        ...        ...
# 2995   3422    Jakobe    Erickson  22-Jun-22  07-Aug-22
# 2996   3423    Adyson  Strickland  28-Dec-20        NaN
# 2997   3424   Annabel     Wilkins  09-Dec-20  04-Aug-22
# 2998   3425    Kendra       Braun  28-May-19  23-Oct-21
# 2999   3426     Chace        Kerr  27-Apr-22        NaN
#
#                         Title          Supervisor  \
# 0     Production Technician I        Peter Oneill
# 1     Production Technician I     Renee Mccormick
# 2          Area Sales Manager      Crystal Walker
# 3          Area Sales Manager      Rebekah Wright
# ...

# %% [markdown]
# # fillna

# %%
df.fillna(0)

# %%
df['ExitDate'].fillna("not specified",inplace=True)

# %%
df

# %%
df['StartDate'].fillna(1)
# Out:
# 0       20-Sep-19
# 1       11-Feb-23
# 2       10-Dec-18
# 3       21-Jun-21
# 4       29-Jun-19
#           ...
# 2995    22-Jun-22
# 2996    28-Dec-20
# 2997    09-Dec-20
# 2998    28-May-19
# 2999    27-Apr-22
# Name: StartDate, Length: 3000, dtype: object
