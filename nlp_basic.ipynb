# %%
text="text mining is a powerful tool for extracting insights from large dataset"
print(text)
# Out:
# text mining is a powerful tool for extracting insights from large dataset

# %%
corpus=["my name is mandeep sahu ",
       "i am from jharkhand ranchi",
       "i solved 100+ questions on leetcode"]
print(corpus)
# Out:
# ['my name is mandeep sahu ', 'i am from jharkhand ranchi', 'i solved 100+ questions on leetcode']

# %%
#tokenizing using simple split
tokens=text.split()
print(tokens)
# Out:
# ['text', 'mining', 'is', 'a', 'powerful', 'tool', 'for', 'extracting', 'insights', 'from', 'large', 'dataset']

# %%
nltk.download("punkt")
nltk.download("punkt_tab")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\nisha\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\nisha\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
import nltk
nltk.download('punkt')  #dowanload punkt tokenizer model
from nltk.tokenize import word_tokenize

tokens=word_tokenize(text)
print(tokens)
# Out:
# ['text', 'mining', 'is', 'a', 'powerful', 'tool', 'for', 'extracting', 'insights', 'from', 'large', 'dataset']
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\nisha\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words=set(stopwords.words('english'))
filtered_tokens=[word for word in tokens if word.lower() not in stop_words]
print(filtered_tokens)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\nisha\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# ['text', 'mining', 'powerful', 'tool', 'extracting', 'insights', 'large', 'dataset']

# %%
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()
stems=[stemmer.stem(word) for word in filtered_tokens]
print(stems)
# Out:
# ['text', 'mine', 'power', 'tool', 'extract', 'insight', 'larg', 'dataset']
